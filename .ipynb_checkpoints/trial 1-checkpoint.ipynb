# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels

# %%
from glob import glob
import csv

# %%
dataset = glob('Data/*.csv')

# %%
pd.read_csv(dataset[0])
# Out:
#                     Unnamed: 0      Unnamed: 1  \
# 0              Geography 3 5 6       Age group
# 1                          NaN             NaN
# 2    Newfoundland and Labrador  20 to 24 years
# 3                          NaN             NaN
# 4                          NaN             NaN
# ..                         ...             ...
# 231                        NaN             NaN
# 232                        NaN             NaN
# 233                        NaN             NaN
# 234                        NaN             NaN
# 235                        NaN             NaN
#
#     Type of institution attended 7 8 Elementary/High School College University
# 0                   Reference period                    NaN     NaN        NaN
# 1                                NaN                Percent     NaN        NaN
# 2                        2000 / 2001                      x     13B        23B
# 3                        2005 / 2006                      x     11B        26B
# ...
